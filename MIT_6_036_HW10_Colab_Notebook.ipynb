# %% [markdown]
# <a href="https://colab.research.google.com/github/yangyuegly/6.036HW/blob/new_branch/MIT_6_036_HW10_Colab_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #MIT 6.036 Spring 2019: Homework 10#
#
# This colab notebook provides code and a framework for questions 2, 3, and 4 from [homework 10](https://lms.mitx.mit.edu/courses/course-v1:MITx+6.036+2019_Spring/courseware/Week10/week10_homework/).  You can work out your solutions here, then submit your results back on the homework page when ready.
#
# ## <section>**Setup**</section>
#
# First, download the code distribution for this homework that contains test cases and helper functions.
#
# Run the next code block to download and import the code for this lab.

# %%
# !rm -rf code_for_hw10* __MACOSX data .DS_Store
# !wget --quiet https://introml.odl.mit.edu/cat-soop/_static/6.036/homework/hw10/code_for_hw10.zip
# !unzip code_for_hw10.zip
# !mv code_for_hw10/* .

import code_for_hw10 as code_for_hw10
import mdp10 as mdp

import numpy as np
import math as m
import random

import pdb
from dist import uniform_dist, delta_dist, mixture_dist, DDist
from util import argmax_with_val, argmax
from keras.models import Sequential
from keras.layers.core import Dense
from keras.optimizers import Adam

import importlib
# Out:
# Archive:  code_for_hw10.zip
#    creating: code_for_hw10/
#   inflating: code_for_hw10/code_for_hw10.py
#   inflating: code_for_hw10/dist.py
#   inflating: code_for_hw10/mdp10.py
#   inflating: code_for_hw10/util.py
# Using TensorFlow backend.
# <style>
#        table#id2, #id2 > tbody > tr > th, #id2 > tbody > tr > td {
#          border: 1px solid lightgray;
#          border-collapse:collapse;
#
#         }</style>
# <table id=id2><tr><td id=id2-0-0></td><td id=id2-0-1></td><td id=id2-0-2></td><td id=id2-0-3></td><td id=id2-0-4></td><td id=id2-0-5></td><td id=id2-0-6></td><td id=id2-0-7></td><td id=id2-0-8></td><td id=id2-0-9></td></tr></table>

# %% [markdown]
# # 2) Implement Q-Learning
#
# We'll work up to implementing the Q-learning algorithm by extending our code from HW9. In the next block, please copy and paste your implementations of the following functions from HW9.

# %%
def value_iteration(mdp, q, eps = 0.01, max_iters = 1000):
    def v(s):
        return value(q,s)
    for it in range(max_iters):
        new_q = q.copy()
        delta = 0
        for s in mdp.states:
            for a in mdp.actions:
                new_q.set(s, a, mdp.reward_fn(s, a) + mdp.discount_factor * \
                          mdp.transition_model(s, a).expectation(v))
                delta = max(delta, abs(new_q.get(s, a) - q.get(s, a)))
        if delta < eps:
            return new_q
        q = new_q
    return q

def value(q, s):
    return max(q.get(s, a) for a in q.actions)


def greedy(q, s):
    return argmax(q.actions, lambda a: q.get(s, a))

def epsilon_greedy(q, s, eps = 0.5):
    if random.random() < eps:  # True with prob eps, random action
        return uniform_dist(q.actions).draw()
    else:                   # False with prob 1-eps, greedy action
        return greedy(q, s)

# %% [markdown]
# Run the next code block to make sure what you need from HW9 is working.

# %%
mdp.value = value
mdp.greedy = greedy
mdp.epsilon_greedy = epsilon_greedy
mdp.value_iteration = value_iteration

importlib.reload(code_for_hw10)

# Test: Value Iteration
code_for_hw10.test_solve_play()

# Expected output:
# '''
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# '''
# Out:
# <style>
#        table#id6, #id6 > tbody > tr > th, #id6 > tbody > tr > td {
#          border: 1px solid lightgray;
#          border-collapse:collapse;
#
#         }</style>
# <table id=id6><tr><td id=id6-0-0></td><td id=id6-0-1></td><td id=id6-0-2></td><td id=id6-0-3></td><td id=id6-0-4></td><td id=id6-0-5></td><td id=id6-0-6></td><td id=id6-0-7></td><td id=id6-0-8></td><td id=id6-0-9></td></tr></table>
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100
# Reward 100

# %% [markdown]
# ## 2.1) Q update
#
# First, we'll extend our implementation of the TabularQ class in HW 9 (Problem 5) to incorporate the crucial operation of Q-learning, which is to update the Q value for a given `(s, a)` entry and move it part of the way towards a "target" value *t*.
#
# > *Q(s,a) ← (1−α)Q(s,a) + αt*
#
# Note that this can also be written as:
#
# > *Q(s,a)← Q(s,a)+α(t−Q(s,a))*
#
# That is, move a small (*α*) step towards t.

# %% [markdown]
# Let's define a new method for `TabularQ` that implements this, in a batched form. We will be given a list of `(s, a, t)` triples and have to do all the updates. Note that update is a method of the `TabularQ` class, so you can access the other methods and attributes.
#
# * `data` is a list of `(s, a, t)` tuples.
# * `lr` is a learning rate (*α* above)
# * We will have to update `self.q[(s,a)]` for all of the data.

# %%
class TabularQ:
    def __init__(self, states, actions):
        self.actions = actions
        self.states = states
        self.q = dict([((s, a), 0.0) for s in states for a in actions])
    def copy(self):
        q_copy = TabularQ(self.states, self.actions)
        q_copy.q.update(self.q)
        return q_copy
    def set(self, s, a, v):
        self.q[(s,a)] = v
    def get(self, s, a):
        return self.q[(s,a)]
    def update(self, data, lr):
       for (s, a, t) in data:
            self.q[(s, a)] = (1 - lr) * self.q[(s, a)] + lr * t

# %% [markdown]
# ## 2.2) Q_learn
#
# Complete the definition of the `Q_learn` function. It should update the entries in the `q` function, `(s, a)`, towards their estimated Q values. It should terminate after `iters` iterations and use learning rate `lr`. Use the `q.update` method, which you just wrote, to update the Q values.

# %% [markdown]
# You will need to both simulate the agent's trajectory through the space as well as perform the updates to the Q function estimates. In this version, you should update the Q values after every transition, using a single `(s, a, t)` tuple. **The following methods and functions have already been defined for you.**
#
#
# * To start a new simulation, call `mdp.init_state()`. That will draw a state from the MDP's initial state distribution.
# * You can use the functions that we defined in HW 9: `epsilon_greedy` for action selection (epsilon_greedy takes `(q, s, eps = 0.5)` as input and returns an action) `value` takes `(q, s)` and returns the max Q value for a state.
# * To take a step in the simulation, starting in a given state, `s`, using action a, call `mdp.sim_transition(s,a)`. It will return a pair `(r, s_prime)` denoting the reward received by the agent at that step and the next state.
# * Be careful in treating terminal states. Recall that at a terminal state, there may be an immediate reward but the future expected value will be zero.
# * Return `q` so that the Tutor can test it.

# %%
def Q_learn(mdp, q, lr=.1, iters=100, eps=0.5, interactive_fn=None):
    s = mdp.init_state()
    for i in range(iters):
        a = epsilon_greedy(q, s, eps)
        r, s_prime = mdp.sim_transition(s, a)
        future_val = 0 if mdp.terminal(s) else value(q, s_prime)
        q.update([(s, a, (r + mdp.discount_factor * future_val))], lr)
        s = s_prime
        if interactive_fn: interactive_fn(q, i)
    return q

# %% [markdown]
# Run the next code blocks to test your implementation of `Q_learn`.

# %%
mdp.TabularQ = TabularQ
mdp.Q_learn = Q_learn
importlib.reload(code_for_hw10)

# Test: Tabular Q-learn
code_for_hw10.test_learn_play(iters=100000, tabular=True, batch=False)
# Out:
# <style>
#        table#id8, #id8 > tbody > tr > th, #id8 > tbody > tr > td {
#          border: 1px solid lightgray;
#          border-collapse:collapse;
#
#         }</style>
# <table id=id8><tr><td id=id8-0-0></td><td id=id8-0-1></td><td id=id8-0-2></td><td id=id8-0-3></td><td id=id8-0-4></td><td id=id8-0-5></td><td id=id8-0-6></td><td id=id8-0-7></td><td id=id8-0-8></td><td id=id8-0-9></td></tr></table>
# score (0, 14.2)
# score (10000, 6.0)
# score (20000, 6.7)
# score (30000, 11.5)
# score (40000, 10.8)
# score (50000, 20.9)
# score (60000, 24.7)
# score (70000, 36.0)
# score (80000, 25.6)
# score (90000, 20.4)
# String to upload (incude quotes): "..."
# Reward 100
# Reward 18
# Reward 40
# Reward 100
# Reward 87
# Reward 39
# Reward 28
# Reward 18
# Reward 18
# Reward 18

# %%
def tinyTerminal(s):
    return s==4
def tinyR(s, a):
    if s == 1: return 1
    elif s == 3: return 2
    else: return 0
def tinyTrans(s, a):
    if s == 0:
        if a == 'a':
            return DDist({1 : 0.9, 2 : 0.1})
        else:
            return DDist({1 : 0.1, 2 : 0.9})
    elif s == 1:
        return DDist({1 : 0.1, 0 : 0.9})
    elif s == 2:
        return DDist({2 : 0.1, 3 : 0.9})
    elif s == 3:
        return DDist({3 : 0.1, 0 : 0.5, 4 : 0.4})
    elif s == 4:
        return DDist({4 : 1.0})
      
def testQ():
    tiny = mdp.MDP([0, 1, 2, 3, 4], ['a', 'b'], tinyTrans, tinyR, 0.9)
    tiny.terminal = tinyTerminal
    q = TabularQ(tiny.states, tiny.actions)
    qf = Q_learn(tiny, q)
    ret = list(qf.q.items())
    expected = [((0, 'a'), 0.6649739221724159), ((0, 'b'), 0.1712369526453748), 
                ((1, 'a'), 0.7732751316011999), ((1, 'b'), 1.2034912054227331), 
                ((2, 'a'), 0.37197205380133874), ((2, 'b'), 0.45929063274463033), 
                ((3, 'a'), 1.5156163024818292), ((3, 'b'), 0.8776852768653631), 
                ((4, 'a'), 0.0), ((4, 'b'), 0.0)]
    ok = True
    for (s,a), v in expected:
      qv = qf.get(s,a)
      if abs(qv-v) > 1.0e-5:
        print("Oops!  For (s=%s, a=%s) expected %s, but got %s" % (s, a, v, qv))
        ok = False
    if ok:
      print("Tests passed!")

random.seed(0)
testQ()
# Out:
# Tests passed!

# %% [markdown]
# ## 2.3) Batch Q_learn
#
# Assume your previous update method has been defined.
#
# In the standard Q-learning algorithm, we make one epsilon-greedy transition based on the current Q estimate and then update the Q values. You can think of this as being like stochastic gradient descent. We can also define a version that is more like batch gradient descent, where we generate one or more "episodes" (sequences of transitions) using the current Q values and then update the Q values based on all the observed results. We can also keep around old transitions and use them (all or a random subset) in the update as well. **Note that as our Q value estimate evolves, the target Q value computed from a previously observed transition can change.**
#
# Implement this version of batch Q-learning that (a) generates some specifed number of episodes of a given length (see `sim_episode` below), (b) adds these to the experiences we have seen previously, and (c) updates the Q estimates based on **all the experience so far**. Return `q` so that the Tutor can test it.

# %%
# Simulate an episode (sequence of transitions) of at most
# episode_length, using policy function to select actions.  If we find
# a terminal state, end the episode.  Return accumulated reward a list
# of (s, a, r, s') where s' is None for transition from terminal state.
# Also return an animation if draw=True, or None if draw=False
def sim_episode(mdp, episode_length, policy, draw=False):
    episode = []
    reward = 0
    s = mdp.init_state()
    all_states = [s]
    for i in range(episode_length):
        a = policy(s)
        (r, s_prime) = mdp.sim_transition(s, a)
        reward += r
        if mdp.terminal(s):
            episode.append((s, a, r, None))
            break
        episode.append((s, a, r, s_prime))
        if draw: 
            mdp.draw_state(s)
        s = s_prime
        all_states.append(s)
    animation = animate(all_states, mdp.n, episode_length) if draw else None
    return reward, episode, animation
def Q_learn_batch(mdp, q, lr=.1, iters=100, eps=0.5,
                  episode_length=10, n_episodes=2,
                  interactive_fn=None):
    all_experiences =[]
    for i in range(iters):
      for e in range(n_episodes):
        c_reward, c_episode, c_animation = sim_episode(mdp,episode_length, lambda s : epsilon_greedy(q,s,eps), draw=False)
        all_experiences.append(c_episode)
        all_q_targets =[]
        for ex in all_experiences:
          print(ex)
          future_val = 0 if mdp.terminal(ex[0]) else value(q, ex[3])
          all_q_targets.append(r + mdp.discount_factor * future_val)
        q.update(all_q_targets, lr)
        if interactive_fn: interactive_fn(q, i)
    return q

# %% [markdown]
# **Clarifications**
#
# * There should be a SINGLE call to `q.update` per iteration, not per episode or per experience. Just one call per iteration, with a lot of data.
# * Let's understand the distinction between experiences `(s, a, r, s')` and Q targets `(s, a, t)`. Note that experiences don't depend on the current estimated Q values (only on the environment we are acting in), but the "t" in the Q targets depends on the current Q values. So, it makes sense to store experiences across iterations, but not to store Q targets, since the Q targets change when we update our Q values. Thus, you want to continuously aggregate the experience and then, in each iteration, re-compute the Q targets under the current estimated Q values, then do the update with all of these Q targets. Here's pseudocode:
#
#
# ```
# all_experiences = []
# Loop over n_iterations:
#     Loop over n_episodes:
#         Generate an episode of length episode_length, append this experience to all_experiences
#     all_q_targets = []
#     Loop over all_experiences:
#         Append Q target from one experience to all_q_targets
#         Remember to handle terminal states (where s' = None)
#     q.update(all_q_targets, lr)
# return q
# ```

# %%
def Q_learn_batch(mdp, q, lr=.1, iters=100, eps=0.5,
                  episode_length=10, n_episodes=2,
                  interactive_fn=None):
    all_experiences =[]
    for i in range(iters):
      for e in range(n_episodes):
        c_reward, c_episode, c_animation = sim_episode(mdp,episode_length, lambda s : epsilon_greedy(q,s,eps), draw=False)
        all_experiences.extend(c_episode)
        all_q_targets =[]
      for ex in all_experiences:
        future_val = 0 if mdp.terminal(ex[0]) else value(q, ex[3])
        all_q_targets.append((ex[0],ex[1],ex[2] + mdp.discount_factor * future_val))
      q.update(all_q_targets, lr)
      if interactive_fn: interactive_fn(q, i)
    return q

# %% [markdown]
# Run the next code blocks to test your implementation of `Q_learn_batch`.

# %%
mdp.Q_learn_batch = Q_learn_batch
importlib.reload(code_for_hw10)

# Test: Tabular Batch Q-learn
code_for_hw10.test_learn_play(iters=10, tabular=True, batch=True) # Check: why do we want fewer iterations here?
# Out:
# <style>
#        table#id18, #id18 > tbody > tr > th, #id18 > tbody > tr > td {
#          border: 1px solid lightgray;
#          border-collapse:collapse;
#
#         }</style>
# <table id=id18><tr><td id=id18-0-0></td><td id=id18-0-1></td><td id=id18-0-2></td><td id=id18-0-3></td><td id=id18-0-4></td><td id=id18-0-5></td><td id=id18-0-6></td><td id=id18-0-7></td><td id=id18-0-8></td><td id=id18-0-9></td></tr></table>
# score (0, 6.0)
# score (1, 11.3)
# score (2, 15.1)
# score (3, 27.5)
# score (4, 18.9)
# score (5, 13.2)
# score (6, 7.2)
# score (7, 25.4)
# score (8, 15.4)
# score (9, 27.2)
# String to upload (incude quotes): ""
# Reward 6
# Reward 6
# Reward 6
# Reward 52
# Reward 6
# Reward 6
# Reward 6
# Reward 6
# Reward 52
# Reward 6

# %%
def testBatchQ():
    tiny = mdp.MDP([0, 1, 2, 3, 4], ['a', 'b'], tinyTrans, tinyR, 0.9)
    tiny.terminal = tinyTerminal
    q = TabularQ(tiny.states, tiny.actions)
    qf = Q_learn_batch(tiny, q)
    ret = list(qf.q.items())
    expected = [((0, 'a'), 4.7566600197286535), ((0, 'b'), 3.993296047838986), 
                ((1, 'a'), 5.292467934685342), ((1, 'b'), 5.364014782870985), 
                ((2, 'a'), 4.139537149779127), ((2, 'b'), 4.155347555640753), 
                ((3, 'a'), 4.076532544818926), ((3, 'b'), 4.551442974149778), 
                ((4, 'a'), 0.0), ((4, 'b'), 0.0)]

    ok = True
    for (s,a), v in expected:
      qv = qf.get(s,a)
      if abs(qv-v) > 1.0e-5:
        print("Oops!  For (s=%s, a=%s) expected %s, but got %s" % (s, a, v, qv))
        ok = False
    if ok:
      print("Tests passed!")
      
      return list(qf.q.items())

random.seed(0)
testBatchQ()

# %% [markdown]
# # 3) NN Q
#
# Now we will combine neural networks with Q-learning. There are a wide variety of ways to do this, some of which are referred to as "deep Q-learning". They all hinge on the following ideas, which are explained in depth in the notes:
#
# * We would like to operate in large or continuous state and/or action spaces so it is not possible (or effective) to store the *Q* values in a table; instead, we will "store" them by training a neural network to do regression for us, taking *s, a* as input and generating (an approximation of) *Q∗(s,a)* as output.
# * To train the network, we will use *squared Bellman error* as the loss function (see [homework 10](https://lms.mitx.mit.edu/courses/course-v1:MITx+6.036+2019_Spring/courseware/Week10/week10_homework/) for equation).

# %% [markdown]
# We will explore two different algorithms and one input representation. There are many choices of neural network architecture. We are going to work on a problem with a very small set (size 3) of actions and we will:
#
# * Make one neural network for each possible action *a*.
# * Design that network with 2 **hidden** layers, with ReLU units, and a single linear output unit; and
# * Use mean squared error (mse) as the loss function since we are doing regression
# * Use `Adam()` as your optimizer.

# %%
# In Keras, we would create such a network using the following function
# please evaluate this cell so you can use it in your code

def make_nn(state_dim, num_hidden_layers, num_units):
    '''
    state_dim =	(int) number of states
    num_hidden_layers =	(int) number of	fully connected hidden layers
    num_units =	(int) number of	dense relu units to use	in hidden layers
    '''  
    model = Sequential()
    model.add(Dense(num_units, input_dim = state_dim, activation='relu'))
    for i in range(num_hidden_layers-1):
        model.add(Dense(num_units, activation='relu'))
    model.add(Dense(1, activation='linear'))
    model.compile(loss='mse', optimizer=Adam())
    return model

# %% [markdown]
# ## 3.1) Basic neural network Q-learning
#
# We'll call the first algorithm *basic neural network Q-learning*. It was the first strategy to be used to combine Q-learning and neural networks, and suffers from the *correlated experience* problem described in the notes. However, it is relatively easy to implement and works okay on very simple problems.
#
# In basic NN Q-learning, just as in the version of Q-learning we implemented above, you simulate a trajectory through state space, using *ϵ*-greedy action selection, and making an update to your Q functions after each piece of experience *(s, a, r, s′)*. You do this by doing one epoch of training on your network for action *a*, on a data set made up of a single data point, where the input is *s* and the desired output is *r + γ max_a' Q(s', a')*, using the current estimates of *Q*.
#
# This might sound very familiar. In fact, it is exactly `Q_learn` except that instead of using a tabular representation of the the Q function, we are using a neural net to approximate the Q values for the state. In particular, the update method corresponds to training the neural net with the target Q value.
#
# To use a neural net implementation of Q values, for a given action, we will need to have a mapping from states to fixed-length row vectors. We will assume that the `MDP` class has a `state2vec` method that maps states to vectors. For the simple MDPs we have seen so far, this simply returns a one-hot representation of the state.
#
# Now, all we need is to write a new class to implement the Q function and then we should be able to use the `Q_learn` directly to do Neural Net Q-learning (NNQ). **The arguments to the `get` and `update` methods are the same as those in `TabularQ`; please review those now.**

# %% [markdown]
# We will assume that we have a small number of actions and we will use a neural net to learn the Q values for each action. Keep a dictionary of these NN models in `self.models` using the action as the key. Note that you have access to `make_nn` which was previously described.
#
# For each `update` call, create one training set for each action *a*:
#
# 1. Extract the tuples from your data set that contain action aa. Recall that the `data` tuples are of the form `(s, a, t)`, where t is a target Q value.
# 2. Let the *X* values of your training set be all of the *s* values from your data tuples with action *a* and the *Y* values be the target Q values given in the data tuples.
#
# Train the network for action *a* for the specified number of epochs, using `self.models[a].fit(X, Y, epochs=epochs)`. In Basic Q-Learning, we will always use `epochs=1`, but make this a general argument in creating an instance of the class. **Ignore the `lr` argument to the `update` method, we'll let Adam pick learning rates.**

# %%
class NNQ:
    def __init__(self, states, actions, state2vec, num_layers, num_units, epochs=1):
        self.actions = actions
        self.states = states
        self.state2vec = state2vec
        self.epochs = epochs
        self.state_dim = state2vec(states[0]).shape[1]
        self.models = dict([(a, make_nn(self.state_dim, num_layers, num_units)) for a in actions])              # Your code here
    def get(self, s, a):
        return self.models[a].predict(self.state2vec(s))
    def update(self, data, lr):
      for a in self.actions:
        X=[]
        Y=[]
        for i in range(len(data)):
          if data[i][1] == a:
            X.append(self.state2vec(data[i][0])[0])
            Y.append(data[i][2])
        shape = len(Y)
        X_len = len(X)
        X = np.array(X)
        Y = np.array(Y)
        Y=Y.reshape((shape,1))
        X=X.reshape((shape,self.state_dim))
        if X_len!=0:
            self.models[a].fit(X,Y, epochs=self.epochs)

# %% [markdown]
# Run the next code blocks to test your implementation of `NNQ`.

# %%
mdp.NNQ = NNQ
importlib.reload(code_for_hw10)

# Test: NN Q-learn
code_for_hw10.test_learn_play(iters=100000, tabular=False, batch=False)
# Out:
# <style>
#        table#id24, #id24 > tbody > tr > th, #id24 > tbody > tr > td {
#          border: 1px solid lightgray;
#          border-collapse:collapse;
#
#         }</style>
# <table id=id24><tr><td id=id24-0-0></td><td id=id24-0-1></td><td id=id24-0-2></td><td id=id24-0-3></td><td id=id24-0-4></td><td id=id24-0-5></td><td id=id24-0-6></td><td id=id24-0-7></td><td id=id24-0-8></td><td id=id24-0-9></td></tr></table>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1
# 1/1 [==============================] - 0s 239ms/step - loss: 0.9284
# score (0, 12.0)
# Epoch 1/1
# 1/1 [==============================] - 0s 181ms/step - loss: 1.1884
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1730
# Epoch 1/1
# 1/1 [==============================] - 0s 216ms/step - loss: 2.5270
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6355
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7901
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7727
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7808
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0039
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0167
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6373
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1683
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1256
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9638
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 6.7750
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9559
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9712e-05
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6115
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2224
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2600
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1404
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0199
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0752
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1020
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9829
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5288
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 5.9815
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5799
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0625
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3457
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5565e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0039
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0283
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6354
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3560
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8648
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5514
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2131
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4455
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3247
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0760
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 16.1949
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0518
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0153
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0455
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8217
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6733
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2931
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7770
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2906
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6760
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6285
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6285
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3739
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0725
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5639
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2652
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 30.8726
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2899
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0588
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 68.7316
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1983
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1756
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 12.6266
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 5.5924
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7923
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 33.1210
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 32.4580
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2541
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 16.5076
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0040
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 19.2038
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 23.7983
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 35.5558
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 35.2246
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 36.4171
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0583
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7304
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6593
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8446e-06
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1131
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 14.2953
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 4.5902
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 30.6149
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8313
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 47.0530
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9390
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7721
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5324
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5176
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 15.0120
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0757
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1713
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1260
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0239
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7542
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7783
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 11.7386
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6413
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2849
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0149
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7325
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0826
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 20.8240
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9860
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0868
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0960
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8048
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 5.5768
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9525
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 11.2630
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2511
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8078
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 20.7047
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7921
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6764
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5488
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 11.4848
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9128
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5484
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 21.8948
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6659
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6798
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1021
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0959
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 16.3624
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 18.2968
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 23.6938
# Epoch 1/1
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5218
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5619
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0640
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0759
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0723
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1133
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 22.1718
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0435
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0587
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3066
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 6.3385
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 8.0176
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9215
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7039
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2939
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6178
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1080
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1352
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1969
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 5.4279
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 9.5822
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2255
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7887
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9149
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0946
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7531
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9509
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 7.4814
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1738
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2575
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0587
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 3.8620
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0503
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 6.0187
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5273
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6191
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9766
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8187
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 3.5002
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2328
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 7.3104
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8386
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0118
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0281
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 10.8948
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2418
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0462
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 7.1510
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4952
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0111
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9136
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 5.0043
# Epoch 1/1
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0535
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2348
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7460
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9233
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2681
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2278
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0198
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0157
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0175
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0555
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3872
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4369
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 5.0566
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 6.0397
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 6.4130
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 5.3573
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 8.6923
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4775
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 7.6514
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1522
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1802
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4137
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3827
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3895
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9714
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 11.3915
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3503
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6100
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1924
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1933
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 3.8723
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 5.4491
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0874
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0584
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3203
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0149
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6174
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1900
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2846
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3226
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3960
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7948
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0169
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7559
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5015
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1984
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9282
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0123
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9717
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8345
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4152
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7073
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 6.6561
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9302
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6663
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4583
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2548
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8585
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0152
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0160
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8836
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1883
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8837
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5578
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7278
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1579
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 7.0696
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8564
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 4.6600
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1059
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8760
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1747
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0221
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0846
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7010
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 27.7094
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5562
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0945
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7608
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7372
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9303
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 14.7043
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5548
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1538
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 4.1471
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2129
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8412
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 20.5230
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1113
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 4.1294
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1157
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0666
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0539
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 6.1535
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 10.9398
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4875
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7377
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8601
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3734
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0317
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3483
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 14.1760
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1261
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 5.0948
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9777
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0245
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9090
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9831
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 12.1961
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4471
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3842
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0384
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0226
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2232
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 23.3654
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3860
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1859
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 6.0322e-05
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3988e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1993
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1870
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 17.4337
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3408
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6424
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8439
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6958
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7872
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8768
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 4.7765
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3381
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 4.7213e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1989
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1818
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8379
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 26.0492
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2934
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5916
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7147
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1737
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6533
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0117
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2189
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3920
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2424
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1086
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0575
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 5.5038
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7927
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7603
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2632
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 6.9069
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9761
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1299
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 32.0656
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2218
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5901
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1989
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0317
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1621
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3096
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6988
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3506
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3077
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2872
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8116
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2284
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0283
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1552
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3006
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1693
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 3.5468
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4855
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0454
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0835
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2185
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0416
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1901
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 6.3973
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 8.9407
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 6.4097
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7659
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0077
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5636
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0434
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4818
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0317
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5598
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3636
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7224
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5308
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 8.1359
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0346
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5481
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 9.6628e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8598e-05
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1576
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5788
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 15.1733
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3321
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4264
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0932
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 4.3161
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3722
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 5.8135
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 16.0041
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2978
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8216
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5721
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6683
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5002
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0433
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9400
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0610
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4735
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9852
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1205
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7834
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3570
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 5.2210
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0892
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0080
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1063
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8480
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5328
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6635
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8111
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0110
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5129
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0155
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1971
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0774
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3707
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 8.2598
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3948
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9959
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1853
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4708
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3672
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 7.7712
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 8.6214
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9981
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 5.1655
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3217
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2206
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6847
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4670
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0343
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1492
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0447
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2111
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1426
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4344
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2636
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3923
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0325
# Epoch 1/1
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3264
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9818e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5097
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 7.0928
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0903
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5984
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7117
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0035
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1599
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2288
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0188
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5541
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 6.3182
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0416
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0127
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4976
# Epoch 1/1
# 1/1 [==============================] - 0s 5ms/step - loss: 1.8174
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0246
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3048
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0334
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0547
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4626
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5843
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 1/1
# 1/1 [==============================] - 0s 7ms/step - loss: 49.4622
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4942
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0842
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1707
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3253
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3007
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1442
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0585
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7999
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9036
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3399
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7349
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6063
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5340
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0462
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1189
# Epoch 1/1
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0671
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1035
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6609
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2902
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6707
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0530
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2353
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0337
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1575
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0056
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 7.4032e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0490
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0296
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5004
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1750
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 36.2164
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4728
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3077
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0531
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7426
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3312
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2544
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 4.8973
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1504
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5327
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3553
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7197
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2813
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4867
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0178
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4600
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0333
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 8.4409e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5376
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5962
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2668
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0389
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0588
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4999
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6867
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1260
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4018
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0429
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0192
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0566
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4079
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 6.8652
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2812
# Epoch 1/1
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2119
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5263
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2080
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0257
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3452
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8651
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3341
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9076
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2997
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3771
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4042
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4220
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1910
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4608
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4855
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4805
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 5.0104
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0598
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2175
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7726
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5026
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0234
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0234
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2751
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3514
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6538
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 16.6555
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3709
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1328
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4550
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6980
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8514
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1826
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0838
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4089
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8089
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6147
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7586
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 20.3687
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3928
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1490
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1294
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8197
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0652
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0978
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0952
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5292
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4005
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0660
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9690
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0657
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0123
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2075
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0668
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7289
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0380
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4326
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0316
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8672
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3983
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8275
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9615
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1592
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2827
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0864
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 30.7849
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4239
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8790
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6605
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1571
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0541
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 4.0577
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 16.4461
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4054
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4005
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0121
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0517
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0890
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0684
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0527
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3573
# Epoch 1/1
# ...
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0991
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2634
# Epoch 1/1
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0679
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2580
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2813
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0927
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0240
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0599e-06
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3009
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1009
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0125
# Epoch 1/1
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0192
# Epoch 1/1
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3111
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6918
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 4.2243
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 9.4276e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0231
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2001
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4675
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8720
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7215e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0137
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 5.0657e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0275
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4906
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0324
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0136
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 4.1118
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0174
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0256
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2302
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4353
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2976
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1588e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 14.2517
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7676
# Epoch 1/1
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0108
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1017
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0036
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0439
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8424
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0442
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0176
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1931
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1549
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5826
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1667
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9663e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0660
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0098
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2320
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1208
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6473
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2130
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0994
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4442
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 7.5345
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0262
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0449
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1400
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0182
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0173
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3173
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8330
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0519
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0197
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0349
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1567
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2176
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1102
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5777
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1825
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0078
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4219
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1890
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0195
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4871
# Epoch 1/1
# 1/1 [==============================] - 0s 10ms/step - loss: 2.3436
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6798
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0468
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 5.8793e-06
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3427
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6491
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0509
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0119
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0172
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2699
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9173
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1454
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0998
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1557
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1144
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0248
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0443
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1366
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2084
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2016
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 9.6684e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0122
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0251
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0644
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2713
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1270
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2734
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1680
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1116
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4340
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3176
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0758
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0785
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0232
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 9.3631e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1313
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1794
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6467
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2307
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4243
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0130
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1552
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9049
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 13.9886
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 1/1
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0530
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0306
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2261
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3980
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0843
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3099
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0411
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 7.7999e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4376e-05
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0908
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5656
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 5.1296
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0112
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0469
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7483
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0642
# Epoch 1/1
# 1/1 [==============================] - 0s 16ms/step - loss: 8.4407
# Epoch 1/1
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3996
# Epoch 1/1
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2988
# Epoch 1/1
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0389
# Epoch 1/1
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0509
# Epoch 1/1
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0018
# Epoch 1/1
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0333
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0044
# Epoch 1/1
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1733
# Epoch 1/1
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1415
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5036
# Epoch 1/1
# 1/1 [==============================] - 0s 6ms/step - loss: 3.2062
# Epoch 1/1
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7063
# Epoch 1/1
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0020
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0287
# Epoch 1/1
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0430
# Epoch 1/1
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0906
# Epoch 1/1
# 1/1 [==============================] - 0s 6ms/step - loss: 2.3597e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0020
# Epoch 1/1
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7945
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0184
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0308
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 1/1
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1040
# Epoch 1/1
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1239
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0231
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0236
# Epoch 1/1
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0026
# Epoch 1/1
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6499
# Epoch 1/1
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6580
# Epoch 1/1
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5983
# Epoch 1/1
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1032
# Epoch 1/1
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3854e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0964
# Epoch 1/1
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3360
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3013
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1310
# Epoch 1/1
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3813
# Epoch 1/1
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0183
# Epoch 1/1
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4651e-04
# Epoch 1/1
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0063
# Epoch 1/1
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0035
# Epoch 1/1
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1434
# Epoch 1/1
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0388
# Epoch 1/1
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2068
# Epoch 1/1
# 1/1 [==============================] - 0s 12ms/step - loss: 8.2053
# Epoch 1/1
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0168

# %%
def test_NNQ(data):
    tiny = mdp.MDP([0, 1, 2, 3, 4], ['a', 'b'], tinyTrans, tinyR, 0.9)
    tiny.terminal = tinyTerminal
    q = NNQ(tiny.states, tiny.actions, tiny.state2vec, 2, 10)
    q.update(data, 1)
    ret =  [q.get(s,a) for s in q.states for a in q.actions]
    expect = [np.array([[-0.07211456]]), np.array([[-0.19553234]]), 
              np.array([[-0.21926211]]), np.array([[0.01699455]]), 
              np.array([[-0.26390356]]), np.array([[0.06374809]]), 
              np.array([[0.0340214]]), np.array([[-0.18334733]]), 
              np.array([[-0.438375]]), np.array([[-0.13844737]])]
    cnt = 0
    ok = True
    for s in q.states:
      for a in q.actions:
        if not np.all(np.abs(ret[cnt]-expect[cnt]) < 1.0e0):
          print("Oops, for s=%s, a=%s expected %s but got %s" % (s, a, expect[cnt], ret[cnt]))
          ok = False
        cnt += 1
    if ok:
      print("Output looks generally ok")
    return q
  
test_NNQ([(0,'a',0.3),(1,'a',0.1),(0,'a',0.1),(1,'a',0.5)])

# %% [markdown]
# ## 3.2) Fitted Q iteration
#
# *Fitted Q iteration (FQ)* suffers less from the correlated experience problem and is generally more stable (and sometimes slower) than NNQ.
#
# FQ initializes the Q networks and an empty data set, then operates in a loop:
#
# > Indented block
#
#
#
# 1. Use *ϵ*-greedy exploration to generate *k* steps of experience, of the form *(s,a,r,s′)* and add them to the data set.
# 2. Create one training set for each action *a*:
#
# > 1. Extract all the tuples from your data set that contain action *a*,
# > 2. Let the *X* values of your training set be all of the *s* values from your data tuples with action *a* and the *Y* values be the *r + γ max_a' Q(s', a')* values computed for each data tuple, using the Q estimates from the current network.
#
# 3. Train the network for action *a* for several epochs until it has done a good job of representing this data.
#
# So, this is basically `Q_learn_batch` using `NNQ` (training with multiple epochs) to implement the Q function.

# %% [markdown]
# Run the next code block to test your implementation of `NNQ` with batching.

# %%
# Test: NN Batch Q-learn (Fitted Q-learn)
code_for_hw10.test_learn_play(iters=10, tabular=False, batch=True)

# %% [markdown]
# #4) No Exit
#
# Please read the instructions in the [homework](https://lms.mitx.mit.edu/courses/course-v1:MITx+6.036+2019_Spring/courseware/Week10/week10_homework/) to set up for the game. You may use this space to display the game in Colab.

# %%
# NN Q-learn
code_for_hw10.test_learn_play(draw=True, iters=100000, tabular=False, batch=False)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-43-def5061d6dc5> in <module>()
# ----> 1 code_for_hw10.test_learn_play(draw=True, iters=100000, tabular=False, batch=False)
#
# /content/code_for_hw10.py in test_learn_play(d, num_layers, num_units, eps, iters, draw, tabular, batch, batch_epochs, num_episodes, episode_length)
#     232     else:
#     233         q = NNQ(game.states, game.actions, game.state2vec, num_layers, num_units,
# --> 234                 epochs=batch_epochs if batch else 1)
#     235     if batch:
#     236         qf = Q_learn_batch(game, q, iters=iters, episode_length = 100, n_episodes=10,
#
# /content/mdp10.py in __init__(self, states, actions, state2vec, num_layers, num_units, epochs)
#     213         self.epochs = epochs
#     214         self.models = None              # Your code here
# --> 215         if self.models is None: raise NotImplementedError('NNQ.models')
#     216     def get(self, s, a):
#     217         # Your code here
#
# NotImplementedError: NNQ.models
